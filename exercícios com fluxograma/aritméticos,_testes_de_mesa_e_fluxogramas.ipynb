# %% [markdown]
# <a href="https://colab.research.google.com/github/paolaonzara/logicadeprogramacaopython/blob/main/exerc%C3%ADcios%20com%20fluxograma/aritm%C3%A9ticos%2C_testes_de_mesa_e_fluxogramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Valor Total
# ![valor quantidade.PNG](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
valor = float (input("Digite o valor da peça: "))
quantidade = float (input("Digite a quantidade de peças: "))
# Out:
# Digite o valor da peça: 5
# Digite a quantidade de peças: 5

# %%
#processamento
valor total = valor*quantidade
# Out:
#   File "<ipython-input-8-9b71095d7697>", line 2
#     valor total = valor*quantidade
#           ^
# SyntaxError: invalid syntax

# %%
#saida
print("O valor total é: ", valor total)

# %% [markdown]
# #Média entre dois valores
# ![p1, p2.PNG](data:image/png;base64,...)
#
# ![Media nota.PNG](data:image/png;base64,...)

# %%
#entrada
valor1 = float (input("Digite o primeiro valor: "))
valor2 = float (input("Digite o segundo valor: "))
# Out:
# Digite o primeiro valor: 5
# Digite o segundo valor: 5

# %%
#processamento
media = (valor1+valor2)/2

# %%
#saida
print("A media é: ", media)
# Out:
# A media é:  5.0

# %% [markdown]
# #Converter para dólar
# ![conversão dolar real.PNG](data:image/png;base64,...)
#
# ![dolar.PNG](data:image/png;base64,...)

# %%
#entrada
real = float(input("Digite o valor em reais: "))
dolar = float(input("Digite o valor atual do dolar em reais: "))
# Out:
# Digite o valor em reais: 5
# Digite o valor atual do dolar em reais: 5

# %%
#processamento
valor = real*dolar

# %%
#saida
print("O valor convertido é: ", valor)
# Out:
# O valor convertido é:  25.0

# %% [markdown]
# #Soma dos quadrados
# ![Soma dos quadrados.PNG](data:image/png;base64,...)
#
# ![soma quadrados.PNG](data:image/png;base64,...)

# %%
#entrada
n1 = float(input("Digite o numero: "))
n2 = float(input("Digite o numero: "))
n3 = float(input("Digite o numero: "))
n4 = float(input("Digite o numero: "))
# Out:
# Digite o numero: 2
# Digite o numero: 2
# Digite o numero: 2
# Digite o numero: 2

# %%
#processamento
total = (n1*n1)+(n2*n2)+(n3*n3)+(n4*n4)

# %%
#saida
print("O total é: ", total)
# Out:
# O total é:  16.0

# %% [markdown]
# #Comissão
# ![comissão vendedor.PNG](data:image/png;base64,...)
#
# ![comissao venda.PNG](data:image/png;base64,...)

# %%
#entrada
preco = float(input("Digite o preço: "))
quantidade = float(input("Digite a quantidade vendida: "))
porcentagem = float(input("Digite a porcentagem que ira ganhar: "))
# Out:
# Digite o preço: 2.5
# Digite a quantidade vendida: 200
# Digite a porcentagem que ira ganhar: 5

# %%
#processamento
comissao = (preco*quantidade)*porcentagem/100

# %%
#saida
print("A comissão é: ", comissao)
# Out:
# A comissão é:  25.0

# %% [markdown]
# #Valor Carro
#  ![valor consumidor.PNG](data:image/png;base64,...)
#
#  ![custo fabri.PNG](data:image/png;base64,...)

# %%
#entrada
custo = float(input("Digite o custo: "))
porcd = float(input("Digite a percentagem do distribuidor: "))
impos = float(input("Digite o valor dos impostos: "))

#processamento
valor = (custo*impos/100+custo)+(custo*impos/100+custo)*porcd/100
#saida
print("O valor para consumidor é: ", valor)
# Out:
# Digite o custo: 25000
# Digite a percentagem do distribuidor: 28
# Digite o valor dos impostos: 45
# O valor para consumidor é:  46400.0

# %% [markdown]
# #Minutos e horas em segundos
# ![horas para segundos.PNG](data:image/png;base64,...)
#
# ![conversao segundos.PNG](data:image/png;base64,...)

# %%
#entrada
horas = float(input("Digite as horas: "))
minutos = float(input("Digite os minutos: "))

#processamento
conversao = (minutos/60)+horas

#saida
print("A conversao para segundos é;: ", conversao)
# Out:
# Digite as horas: 4
# Digite os minutos: 23
# A conversao para segundos é;:  4.383333333333334

# %% [markdown]
# #Hora extra
# ![hora extra.PNG](data:image/png;base64,...)
#
# ![hora extra.PNG](data:image/png;base64,...)

# %%
#entrada
hora=float(input("Digite a hora: "))
min=float(input("Digite o minuto : "))
ganho=float(input("Digite o ganho por hora : "))
comissao=float(input("Digite a sua comissão : "))
#procesamento

minc= (min/60)
ganhoph=(minc+hora)*ganho
comis=(comissao*ganhoph)/100
vl=comis+ganhoph
# saida
print ("O valor ganho por hora é: ",vl )

# %% [markdown]
# #Preço gasolina
# ![preço gasolina.PNG](data:image/png;base64,...)
#
# ![Gasto gasolina.PNG](data:image/png;base64,...)

# %%
#entrada

kl=float(input("Digite os kilometros a serem percorridos: "))
conM=float(input("Digite o consumo médio de gasolinna do seu carro : "))
prec=float(input("Digite o preço médio da gasolina : "))

#procesamento
consumo=kl/conM
preco=consumo*prec
# saida
print ("O valor de gasolina será : ",preco )

# %% [markdown]
# #Velocidade media
# ![velocidade média.PNG](data:image/png;base64,...)
#
# ![velocidade media.PNG](data:image/png;base64,...)

# %%
#entrada
dis=float(input("Digite a disitancia percorrida: "))
temp=float(input("Digite o tempo gasto em horas : "))
temp2=float(input("Digite o tempo gasto em minutos : "))

#procesamento
min=(temp2/60)
tempo=min+temp
media=dis/tempo

# saida
print ("A velocidade Média é: ",media )
